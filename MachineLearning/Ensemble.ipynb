# %% [markdown]
# # Ensenble 앙상블
#
# - [ ] DecisionTree, RandomForest
# - [ ] GradientBoost
#     - [ ] XGBoost
#     - [ ] AdaBoost
#     - [ ] CatBoost
#     - [ ] LightGBM

# %% [markdown]
# ## DecisionTree, RandomForest
#
# - DecisionTree : 결정트리 학습법
#     - 한번에 하나의 설명변수를 사용하여 예측 가능한 규칙들의 집합을 생성하는 알고리즘
#     - 데이터를 분석하여, 데이터의 Feature 에서 패턴을 예측 가능한 규칙들의 조합으로 나타내며, 그 모양이 나무와 같다고 해서 ***의사결정트리*** (스무고개)
#         - root node, intermediate node, terminal node
#     - 한 분기마다 변수 영역을 두 개로 구분하는 모델
#    <br/><br/>
#     - 어떠한 기준으로 나뉘는가?
#         - **정보 획득 (information gain)** : ***순도(homogeneity)*** 가 증가하고, ***불순도(impurity) or 불확실성(uncertainty)***이 최대한 감소하도록 하는 방향으로 학습을 진행
#         <br/><br/>
#             * 순도(homogeneity) 계산 방법
#                 - 엔트로피 (entropy)
#                 - 지니계수 (Gini index)
#                 - 오분류오차 (misclassification error)
#         <br/><br/>
#
#     - 분류, 회귀 모두 가능 : 연속형, 범주형 모두 예측 가능
#
#
#
# ***
#
# DecisionTree (ratsgo's blog) : https://ratsgo.github.io/machine%20learning/2017/03/26/tree/
#
#
# 의사결정트리 개념 정리 (Eunsu Kim's blog) :  https://ko.wikipedia.org/wiki/%EA%B2%B0%EC%A0%95_%ED%8A%B8%EB%A6%AC_%ED%95%99%EC%8A%B5%EB%B2%95
# https://eunsukim.me/Decision-Tree/

# %%
from IPython.display import Image
Image("../img/DecisionTree.png") #Yellow : validation fold
